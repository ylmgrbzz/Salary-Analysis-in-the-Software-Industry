# %% [markdown]
# <a href="https://colab.research.google.com/github/ylmgrbzz/Salary-Analysis-in-the-Software-Industry/blob/main/Salary_Analysis_in_the_Software_Industry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
maas=pd.read_csv("maas.csv")

# %%
maas
# Out:
#                    Company Name                             Job Title  \
# 0                      Mu Sigma                        Data Scientist
# 1                           IBM                        Data Scientist
# 2     Tata Consultancy Services                        Data Scientist
# 3              Impact Analytics                        Data Scientist
# 4                     Accenture                        Data Scientist
# ...                         ...                                   ...
# 4339                    TaiyōAI            Machine Learning Scientist
# 4340    Decimal Point Analytics            Machine Learning Developer
# 4341                     MyWays            Machine Learning Developer
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning
# 4343                    vPhrase             Machine Learning Engineer
#
#       Salaries Reported   Location         Salary
# 0                 105.0  Bangalore   ₹6,48,573/yr
# ...

# %%
maas.columns
# Out:
# Index(['Company Name', 'Job Title', 'Salaries Reported', 'Location', 'Salary'], dtype='object')

# %%
maas.columns=["firma","pozisyon","sayi","konum","maas"]
maas
# Out:
#                           firma                              pozisyon   sayi  \
# 0                      Mu Sigma                        Data Scientist  105.0
# 1                           IBM                        Data Scientist   95.0
# 2     Tata Consultancy Services                        Data Scientist   66.0
# 3              Impact Analytics                        Data Scientist   40.0
# 4                     Accenture                        Data Scientist   32.0
# ...                         ...                                   ...    ...
# 4339                    TaiyōAI            Machine Learning Scientist    1.0
# 4340    Decimal Point Analytics            Machine Learning Developer    1.0
# 4341                     MyWays            Machine Learning Developer    1.0
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning    1.0
# 4343                    vPhrase             Machine Learning Engineer    1.0
#
#           konum           maas
# ...

# %%
maas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344 entries, 0 to 4343
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   firma     4341 non-null   object
#  1   pozisyon  4344 non-null   object
#  2   sayi      4342 non-null   float64
#  3   konum     4344 non-null   object
#  4   maas      4344 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 169.8+ KB

# %%
maas["maas"]
# Out:
# 0        ₹6,48,573/yr
# 1       ₹11,91,950/yr
# 2        ₹8,36,874/yr
# 3        ₹6,69,578/yr
# 4        ₹9,44,110/yr
#             ...
# 4339        ₹5,180/mo
# 4340     ₹7,51,286/yr
# 4341     ₹4,10,952/yr
# 4342    ₹16,12,324/yr
# 4343     ₹9,39,843/yr
# Name: maas, Length: 4344, dtype: object

# %%
import numpy as np 
maas["maas"]=maas["maas"].str.replace("₹","")

# %%
x=maas["maas"].str.split("/",expand=True)

# %%
x.head(3)
# Out:
#            0   1
# 0   6,48,573  yr
# 1  11,91,950  yr
# 2   8,36,874  yr

# %%
maas["maas"]=x[0]
maas["birim"]=x[1]

# %%
maas.head(3)
# Out:
#                        firma        pozisyon   sayi      konum       maas  \
# 0                   Mu Sigma  Data Scientist  105.0  Bangalore   6,48,573
# 1                        IBM  Data Scientist   95.0  Bangalore  11,91,950
# 2  Tata Consultancy Services  Data Scientist   66.0  Bangalore   8,36,874
#
#   birim
# 0    yr
# 1    yr
# 2    yr

# %%
maas["maas"]=maas["maas"].str.replace(",","")
maas
# Out:
#                           firma                              pozisyon   sayi  \
# 0                      Mu Sigma                        Data Scientist  105.0
# 1                           IBM                        Data Scientist   95.0
# 2     Tata Consultancy Services                        Data Scientist   66.0
# 3              Impact Analytics                        Data Scientist   40.0
# 4                     Accenture                        Data Scientist   32.0
# ...                         ...                                   ...    ...
# 4339                    TaiyōAI            Machine Learning Scientist    1.0
# 4340    Decimal Point Analytics            Machine Learning Developer    1.0
# 4341                     MyWays            Machine Learning Developer    1.0
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning    1.0
# 4343                    vPhrase             Machine Learning Engineer    1.0
#
#           konum     maas birim
# ...

# %%
maas["maas"]=maas["maas"].str.replace("$","9")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
maas["maas"]=maas["maas"].str.replace("£","9")
maas["maas"]=maas["maas"].str.replace("AFN ","9")

# %%
maas["maas"]=maas["maas"].astype("float64")

# %%
maas["maas"]=maas["maas"]*0.19
maas
# Out:
#                           firma                              pozisyon   sayi  \
# 0                      Mu Sigma                        Data Scientist  105.0
# 1                           IBM                        Data Scientist   95.0
# 2     Tata Consultancy Services                        Data Scientist   66.0
# 3              Impact Analytics                        Data Scientist   40.0
# 4                     Accenture                        Data Scientist   32.0
# ...                         ...                                   ...    ...
# 4339                    TaiyōAI            Machine Learning Scientist    1.0
# 4340    Decimal Point Analytics            Machine Learning Developer    1.0
# 4341                     MyWays            Machine Learning Developer    1.0
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning    1.0
# 4343                    vPhrase             Machine Learning Engineer    1.0
#
#           konum        maas birim
# ...

# %%
a=maas["pozisyon"].unique()

# %%
a=list(a)
a
# Out:
# ['Data Scientist',
#  'Data Science Associate',
#  'Data Science Consultant',
#  'Data Science',
#  'Senior Data Scientist',
#  'Junior Data Scientist',
#  'Lead Data Scientist',
#  'Data Science Manager',
#  'Data Scientist - Trainee',
#  'Data Science Lead',
#  'Data Analyst',
#  'Data Engineer',
#  'Machine Learning Engineer',
#  'Machine Learning Software Engineer',
#  'Software Engineer - Machine Learning',
#  'Machine Learning Engineer/Data Scientist',
#  'Machine Learning Consultant',
#  'Machine Learning Data Associate',
#  'Machine Learning Data Associate I',
#  'Machine Learning Associate',
#  'Machine Learning Data Associate II',
#  'Associate Machine Learning Engineer',
#  'Machine Learning Data Analyst',
#  'Senior Machine Learning Engineer',
#  'Machine Learning Scientist',
#  'Machine Learning Developer']

# %%
b=maas["firma"].unique()
b
# Out:
# array(['Mu Sigma', 'IBM', 'Tata Consultancy Services', ...,
#        'Myraa Technologies', 'TaiyōAI', 'Market Pulse Technologies'],
#       dtype=object)

# %%
len(maas["firma"].unique())
# Out:
# 2530

# %%
b=list(b)
b
# Out:
# ['Mu Sigma',
#  'IBM',
#  'Tata Consultancy Services',
#  'Impact Analytics',
#  'Accenture',
#  'Infosys',
#  'Capgemini',
#  'Cognizant Technology Solutions',
#  'Anheuser-Busch InBev',
#  'Fractal',
#  'Embibe',
#  'Amazon',
#  'Google',
#  'Flipkart',
#  'HP Inc.',
#  'Wipro',
#  'Ericsson-Worldwide',
#  'MiQ',
#  'Deloitte',
#  'Microsoft',
#  'Genpact',
#  'Fresher',
#  'Société Générale',
#  'Flutura',
#  'Fuzzy Logix',
#  'DXC Technology',
#  'Jio',
#  'Honeywell',
#  'Affine',
#  'Philips',
#  'Bharat Light & Power',
#  'Antuit',
#  'Nielsen',
#  '[24]7.ai',
#  'Fidelity Investments',
#  'Myntra',
#  'First Student',
#  'Oracle',
#  'Ola',
#  'Walmart Global Tech',
#  'Tredence',
#  'Intel Corporation',
#  'Mercedes-Benz Research and Development India',
#  'SAP',
#  'Wipro Technologies',
#  'Thoucentric',
#  'Walmart',
#  'Brillio',
#  'Great Learning',
#  'Gramener',
#  'HCL Technologies',
#  'Happiest Minds Technologies',
#  'Hewlett Packard Enterprise | HPE',
# ...

# %%
maas.shape
# Out:
# (4344, 6)
